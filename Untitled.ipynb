# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from IPython.display import clear_output
import time

# %%
data = set([])

# %%
for i, href in enumerate(parsing_hrefs[704:]):
    print(f'{i}/{len(parsing_hrefs[704:])}')
    try:
        response = requests.get('https://productcenter.ru'+href)
    except Exception:
        time.sleep(5)
    if not response.status_code==200:
        continue
    try:
        soup = BeautifulSoup(response.content)
    except Exception:
        continue
    name = soup.find('h1', class_='cfix').next_element
    phone = soup.find('span', {'itemprop':'telephone'})
    if phone:
        phone=phone.next_element
    email = soup.find('span', {'itemprop':'email'})
    if email:
        email = email.next_element
    url = soup.find('a', {'itemprop':'url'})
    if url:
        url = url.next_element
    address = soup.find('span', {'itemprop':'addressRegion'}).next_element + ' ' + soup.find('span', {'itemprop':'addressLocality'}).next_element + ' ' + soup.find('span', {'itemprop':'streetAddress'}).next_element
    
    divs = soup.find('div', class_='bc_text').find_all('li')
    inn = entity = ''
    for div in divs:
        if div.next_element.next_element=='Юридическое лицо':
            entity = div.text
        elif div.next_element.next_element=='ИНН':
            inn = div.text
    data.add((name, inn, entity, phone, email, url, address))
    clear_output()
# Out:
# 992/15488
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-a6f23937df12> in <module>
#      11     except Exception:
#      12         continue
# ---> 13     name = soup.find('h1', class_='cfix').next_element
#      14     phone = soup.find('span', {'itemprop':'telephone'})
#      15     if phone:
#
# AttributeError: 'NoneType' object has no attribute 'next_element'

# %%
data = pd.DataFrame(data)

# %%
data.to_excel('from704to1696.xlsx')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3417, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-43-4efa19dce4e1>", line 1, in <module>
#     data.to_excel('from704to1696.xlsx')
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py", line 2023, in to_excel
#     formatter.write(
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\formats\excel.py", line 730, in write
#     writer = ExcelWriter(stringify_path(writer), engine=engine)
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\excel\_openpyxl.py", line 18, in __init__
#     from openpyxl.workbook import Workbook
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\openpyxl\__init__.py", line 6, in <module>
#     from openpyxl.workbook import Workbook
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\openpyxl\workbook\__init__.py", line 4, in <module>
#     from .workbook import Workbook
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\openpyxl\workbook\workbook.py", line 7, in <module>
#     from openpyxl.worksheet.worksheet import Worksheet
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 779, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 874, in get_code
#   File "<frozen importlib._bootstrap_external>", line 973, in get_data
# MemoryError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'MemoryError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\inspect.py", line 744, in getmodule
#     for modname, module in sys.modules.copy().items():
# MemoryError
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3417, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-43-4efa19dce4e1>", line 1, in <module>
#     data.to_excel('from704to1696.xlsx')
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py", line 2023, in to_excel
#     formatter.write(
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\formats\excel.py", line 730, in write
#     writer = ExcelWriter(stringify_path(writer), engine=engine)
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\excel\_openpyxl.py", line 18, in __init__
#     from openpyxl.workbook import Workbook
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\openpyxl\__init__.py", line 6, in <module>
#     from openpyxl.workbook import Workbook
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\openpyxl\workbook\__init__.py", line 4, in <module>
#     from .workbook import Workbook
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\openpyxl\workbook\workbook.py", line 7, in <module>
#     from openpyxl.worksheet.worksheet import Worksheet
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 779, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 874, in get_code
#   File "<frozen importlib._bootstrap_external>", line 973, in get_data
# MemoryError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'MemoryError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3337, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3434, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2046, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1335, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1192, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\inspect.py", line 744, in getmodule
#     for modname, module in sys.modules.copy().items():
# MemoryError
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3417, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-43-4efa19dce4e1>", line 1, in <module>
#     data.to_excel('from704to1696.xlsx')
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py", line 2023, in to_excel
#     formatter.write(
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\formats\excel.py", line 730, in write
#     writer = ExcelWriter(stringify_path(writer), engine=engine)
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\excel\_openpyxl.py", line 18, in __init__
#     from openpyxl.workbook import Workbook
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\openpyxl\__init__.py", line 6, in <module>
#     from openpyxl.workbook import Workbook
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\openpyxl\workbook\__init__.py", line 4, in <module>
#     from .workbook import Workbook
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\openpyxl\workbook\workbook.py", line 7, in <module>
#     from openpyxl.worksheet.worksheet import Worksheet
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 779, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 874, in get_code
#   File "<frozen importlib._bootstrap_external>", line 973, in get_data
# MemoryError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'MemoryError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3337, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3434, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2046, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1335, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1192, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2922, in _run_cell
#     return runner(coro)
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3145, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3356, in run_ast_nodes
#     self.showtraceback()
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2046, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1335, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1210, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "c:\users\cooda\appdata\local\programs\python\python38-32\lib\inspect.py", line 744, in getmodule
#     for modname, module in sys.modules.copy().items():
# MemoryError

# %%
del requests, elements, address, element, response

# %%
sorted(dir(), key=lambda x: x.__sizeof__(), reverse=True)
# Out:
# ['__builtins__',
#  '__builtin__',
#  '__package__',
#  'get_ipython',
#  '__loader__',
#  '__name__',
#  '__spec__',
#  '__doc__',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i39',
#  '_i40',
#  '_i41',
#  '_iii',
#  'data',
#  'divs',
#  'exit',
#  'quit',
#  'Out',
#  '_12',
#  '_15',
#  '_18',
#  '_24',
#  '_26',
#  '_29',
#  '_32',
#  '_35',
#  '_39',
#  '___',
#  '_dh',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_oh',
#  'div',
#  'inn',
#  'url',
#  'In',
#  '_6',
#  '__',
#  '_i',
#  'pd',
#  '_',
#  'i']

# %%
data.to_excel('from704to1696.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-42-6dfde9452716> in <module>
# ----> 1 data.to_excel('from704to1696.xlsx', index=False)
#
# c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2021             inf_rep=inf_rep,
#    2022         )
# -> 2023         formatter.write(
#    2024             excel_writer,
#    2025             sheet_name=sheet_name,
#
# c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     728             need_save = False
#     729         else:
# --> 730             writer = ExcelWriter(stringify_path(writer), engine=engine)
#     731             need_save = True
#     732
#
# c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\excel\_openpyxl.py in __init__(self, path, engine, mode, **engine_kwargs)
#      16     def __init__(self, path, engine=None, mode="w", **engine_kwargs):
#      17         # Use the openpyxl module as the Excel writer.
# ---> 18         from openpyxl.workbook import Workbook
#      19
#      20         super().__init__(path, mode=mode, **engine_kwargs)
#
# c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\openpyxl\__init__.py in <module>
#       4 from openpyxl.compat.numbers import NUMPY, PANDAS
#       5 from openpyxl.xml import DEFUSEDXML, LXML
# ----> 6 from openpyxl.workbook import Workbook
#       7 from openpyxl.reader.excel import load_workbook as open
#       8 from openpyxl.reader.excel import load_workbook
#
# c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\openpyxl\workbook\__init__.py in <module>
#       2
#       3
# ----> 4 from .workbook import Workbook
#
# c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\openpyxl\workbook\workbook.py in <module>
#       5
#       6 from openpyxl.compat import deprecated
# ----> 7 from openpyxl.worksheet.worksheet import Worksheet
#       8 from openpyxl.worksheet._read_only import ReadOnlyWorksheet
#       9 from openpyxl.worksheet._write_only import WriteOnlyWorksheet
#
# c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\openpyxl\worksheet\worksheet.py in <module>
#      16
#      17 # package imports
# ---> 18 from openpyxl.utils import (
#      19     column_index_from_string,
#      20     get_column_letter,
#
# c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\openpyxl\utils\__init__.py in <module>
#       2
#       3
# ----> 4 from .cell import (
#       5     absolute_coordinate,
#       6     cols_from_range,
#
# c:\users\cooda\appdata\local\programs\python\python38-32\lib\site-packages\openpyxl\utils\cell.py in <module>
#      99 for i in range(1, 18279):
#     100     col = _get_column_letter(i)
# --> 101     _STRING_COL_CACHE[i] = col
#     102     _COL_STRING_CACHE[col] = i
#     103
#
# MemoryError:
